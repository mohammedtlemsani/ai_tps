# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv('titanic.csv')
import seaborn as sns

# %%
##les données sont netoyés en utilisant POWER BI
dataset.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Fare'}>,
#         <Axes: title={'center': 'Parents/Children Aboard'}>],
#        [<Axes: title={'center': 'Pclass'}>,
#         <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Siblings/Spouses Aboard'}>],
#        [<Axes: title={'center': 'Survived'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
dataset['Survived'].value_counts()
# Out:
# Survived
# 0    487
# 1    330
# Name: count, dtype: int64

# %%
sns.pairplot(dataset, hue='Survived')
# Out:
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
dataset.corr()
# Out:
#                               Age      Fare  Parents/Children Aboard  \
# Age                      1.000000  0.107156                -0.203584
# Fare                     0.107156  1.000000                 0.203017
# Parents/Children Aboard -0.203584  0.203017                 1.000000
# Pclass                  -0.387949 -0.548349                 0.038934
# Sex                      0.099127 -0.170175                -0.235186
# Siblings/Spouses Aboard -0.308451  0.146354                 0.403822
# Survived                -0.068815  0.243279                 0.063134
#
#                            Pclass       Sex  Siblings/Spouses Aboard  Survived
# Age                     -0.387949  0.099127                -0.308451 -0.068815
# Fare                    -0.548349 -0.170175                 0.146354  0.243279
# Parents/Children Aboard  0.038934 -0.235186                 0.403822  0.063134
# Pclass                   1.000000  0.112604                 0.105392 -0.332440
# ...

# %%
survived = dataset[dataset['Survived'] == 1]
not_survived = dataset[dataset['Survived'] == 0]

# %%
sns.pairplot(survived, hue='Survived')
# Out:
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.pairplot(not_survived, hue='Survived')
# Out:
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\Mohammed Tlemsani\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.hist(not_survived["Pclass"])
# Out:
# (array([ 78.,   0.,   0.,   0.,   0.,  85.,   0.,   0.,   0., 324.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(survived["Pclass"])
# Out:
# (array([135.,   0.,   0.,   0.,   0.,  83.,   0.,   0.,   0., 112.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(not_survived["Parents/Children Aboard"])
# Out:
# (array([383.,  53.,   0.,  40.,   0.,   2.,   4.,   0.,   4.,   1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(survived["Parents/Children Aboard"])
# Out:
# (array([222.,   0.,  64.,   0.,  40.,   0.,   3.,   0.,   0.,   1.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(not_survived["Age"])
# Out:
# (array([ 24.,  18., 120., 121.,  66.,  55.,  42.,  18.,  16.,   7.]),
#  array([ 1. ,  8.3, 15.6, 22.9, 30.2, 37.5, 44.8, 52.1, 59.4, 66.7, 74. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(survived["Sex"])
plt.show()
